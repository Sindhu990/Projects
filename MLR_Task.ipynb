# %% [markdown]
# ## Multiple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\WELCOME\Downloads\multiple_linear_regression_dataset.csv\multiple_linear_regression_dataset.csv")

# %%
data.head()
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830

# %%
data.shape
# Out:
# (20, 3)

# %%
data.describe()
# Out:
#              age  experience        income
# count  20.000000   20.000000     20.000000
# mean   39.650000    6.200000  40735.500000
# std    10.027725    4.124382   8439.797625
# min    23.000000    1.000000  27840.000000
# 25%    31.500000    3.750000  35452.500000
# 50%    40.000000    5.000000  40190.000000
# 75%    47.000000    9.000000  45390.000000
# max    58.000000   17.000000  63600.000000

# %%
data.isnull().sum()
# Out:
# age           0
# experience    0
# income        0
# dtype: int64

# %%
x = data.loc[:,['age','experience']]
y = data['income']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=42)

# %%
x_train.shape
# Out:
# (15, 2)

# %%
x_test.shape
# Out:
# (5, 2)

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pre = model.predict(x_test)
y_pre
# Out:
# array([30811.24112044, 31001.40881574, 40113.19801384, 34665.14126451,
#        38328.87371328])

# %%
r2_score(y_test, y_pre)
# Out:
# 0.921704518922863

# %%
mean_absolute_error(y_test, y_pre)
# Out:
# 926.3665944472938

# %%
mean_squared_error(y_test, y_pre)
# Out:
# 1264016.0265139695

# %%
model.predict([[27,5]])
# Out:
# array([39279.71218975])

# %%
plt.scatter(y_test, y_pre)

# %%
sns.regplot(x=y_test, y=y_pre, ci=None, color='b')
# Out:
# <Axes: xlabel='income'>

# %%
ax = sns.distplot(y_test, hist=False, color='r', label='Actual Values')
sns.distplot(y_pre, hist=False, color='b', label='Fitted Values')
# Out:
# <Axes: xlabel='income', ylabel='Density'>
